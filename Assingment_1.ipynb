# %% [markdown]
# <a href="https://colab.research.google.com/github/saffarizadeh/INSY5378/blob/main/Assingment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://kambizsaffari.com/Logo/College_of_Business.cmyk-hz-lg.png" width="500px"/>
#
# # *INSY 5378*
#
# # **Python Basics Practice Assignment**
#
# Instructor: Dr. Kambiz Saffari
#
# ---

# %% [markdown]
# **Instructions**
# - This assignment reviews Python concepts up to and including **functions**.
# - Do **not** use NumPy or any external libraries.
# - Write your answers directly in the provided cells.
# - You may add additional cells if you want to test ideas, but only answers in the marked cells will be graded.

# %% [markdown]
# ## Question 1: Variables, Types, and Mutability
#
# 1. Create a variable `a` that stores a list with the values `[1, 2, 3]`.
# 2. Assign `b = a`.
# 3. Append the value `4` to `b`.
# 4. Print both `a` and `b`.
# 5. In a comment, explain **why both variables change**.
#
# Then:
# 6. Create a new variable `c` that is an independent copy of `a`.
# 7. Append `5` to `c`.
# 8. Print `a` and `c`.
# 9. In a comment, explain **why `a` does not change this time**.

# %%
# Write your answer to Question 1 here

# %% [markdown]
# ## Question 2: Conditionals and Loops
#
# Write a function called `count_positive_numbers` that:
# - Takes a list of numbers as input
# - Counts how many values are **strictly greater than zero**
# - Returns the count
#
# Then:
# - Call the function using the list `[3, -1, 0, 7, -5, 2]`
# - Print the result

# %%
# Write your answer to Question 2 here

# %% [markdown]
# ## Question 3: Positional vs Keyword Arguments
#
# Consider the function below:
#
# ```python
# def power(base, exponent=2):
#     return base ** exponent
# ```
#
# 1. Call the function using **only positional arguments** to compute \(3^4\).
# 2. Call the function using **keyword arguments** to compute \(5^3\).
# 3. Call the function using **mixed arguments** to compute \(2^5\).
# 4. In a comment, explain **why the order of keyword arguments does not matter**.

# %%
# Write your answer to Question 3 here

# %% [markdown]
# ## Question 4: Writing and Using Functions
#
# Write a function called `summarize_numbers` that:
# - Takes a list of numbers as input
# - Returns a **dictionary** with three keys:
#   - `"min"`: the minimum value
#   - `"max"`: the maximum value
#   - `"count"`: the number of elements in the list
#
# Then:
# - Call the function on the list `[4, 1, 9, -2, 7]`
# - Print the returned dictionary

# %%
# Write your answer to Question 4 here

# %% [markdown]
# ---
# **Submission Reminder**
# - Make sure your notebook runs from top to bottom without errors.
# - Clearly label all answers.
